# %%
import prognum

n = int(input("8："))
result = prognum.fibonacci(n)
print(result)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 3
#       1 import prognum
#       2
# ----> 3 n = int(input("8："))
#       4 result = prognum.fibonacci(n)
#       5 print(result)
#
# ValueError: invalid literal for int() with base 10: ''

# %%
import prognum

n = int(input("何番目の数値を求めますか？："))
result = prognum.fibonacci(n)
print(result)
