# %%
name = input("taro kirameki ")
age = int(input("25"))
print(f"私の名前は {name} です。来年で {age + 1} 歳になります。")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 2
#       1 name = input("taro kirameki ")
# ----> 2 age = int(input("25"))
#       3 print(f"私の名前は {name} です。来年で {age + 1} 歳になります。")
#
# ValueError: invalid literal for int() with base 10: ''
