# %%
import numpy as np

x = np.array([62, 95, 83, 100, 72, 71, 55, 85, 67, 75])   # english
y = np.array([62, 80, 85, 95, 58, 76, 52, 84, 67, 71])    # math
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 import numpy as np
#       2
#       3 x = np.array([62, 95, 83, 100, 72, 71, 55, 85, 67, 75])   # english
#       4 y = np.array([62, 80, 85, 95, 58, 76, 52, 84, 67, 71])    # math
#
# ModuleNotFoundError: No module named 'numpy'

# %%
import matplotlib.pyplot as plt

# 最小二乗法で近似直線の係数を計算
a, b = np.polyfit(x, y, 1)
y_line = a * x + b

# グラフの描画
plt.scatter(x, y, color="blue", label="score")
plt.plot(np.sort(x), a * np.sort(x) + b, color="red", label="lsm")

# ラベルと凡例
plt.xlabel("english")
plt.ylabel("math")
plt.legend(loc="upper left")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import matplotlib.pyplot as plt
#       2
#       3 # 最小二乗法で近似直線の係数を計算
#       4 a, b = np.polyfit(x, y, 1)
#
# ModuleNotFoundError: No module named 'matplotlib'
