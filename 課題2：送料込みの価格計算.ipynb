# %%
price = int(input("税抜価格を入力してください："))
tax_price = round(price * 1.1)

if tax_price >= 2000:
    print("送料は無料です")
    total = tax_price
else:
    print("送料として350円かかります")
    total = tax_price + 350

print(f"送料込みの価格は{total}円です。")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 price = int(input("税抜価格を入力してください："))
#       2 tax_price = round(price * 1.1)
#       4 if tax_price >= 2000:
#
# ValueError: invalid literal for int() with base 10: ''
